# %%
D <- read.csv("box_data_60min.csv", header = TRUE)
D$thour <- D$thour-D$thour[1]+1

## Divide intro train and test set
teststart <- 167
Dtrain <- D[D$thour < teststart, ]
Dtest <- D[D$thour >= teststart, ]

# show first 10 rows of the training set
head(Dtrain, 5)
# Out:
#   thour tdate               Ph Tdelta   Gv         Ph.l0 Ph.l1 Ph.l2 Ph.l3
# 1 1     2013-01-30 02:00:00 56 13.25358 -0.4986434 56    55    57    57
# 2 2     2013-01-30 03:00:00 54 13.18146 -1.1270349 54    56    55    57
# 3 3     2013-01-30 04:00:00 55 12.96879 -0.6432978 55    54    56    55
# 4 4     2013-01-30 05:00:00 54 12.66775 -0.4560078 54    55    54    56
# 5 5     2013-01-30 06:00:00 54 12.60525 -1.5340601 54    54    55    54
#   Ph.l4 ⋯ Gv.l1      Gv.l2      Gv.l3      Gv.l4      Gv.l5      Gv.l6
# 1 58    ⋯ -0.4993379 -0.4179587 -0.2210110 -0.4533753 -0.7472384 -0.6692668
# 2 57    ⋯ -0.4986434 -0.4993379 -0.4179587 -0.2210110 -0.4533753 -0.7472384
# 3 57    ⋯ -1.1270349 -0.4986434 -0.4993379 -0.4179587 -0.2210110 -0.4533753
# 4 55    ⋯ -0.6432978 -1.1270349 -0.4986434 -0.4993379 -0.4179587 -0.2210110
# 5 56    ⋯ -0.4560078 -0.6432978 -1.1270349 -0.4986434 -0.4993379 -0.4179587
#   Gv.l7      Gv.l8      Gv.l9      Gv.l10
# 1 -0.4517765 -0.1427003  8.2623385 20.4754845
# 2 -0.6692668 -0.4517765 -0.1427003  8.2623385
# 3 -0.7472384 -0.6692668 -0.4517765 -0.1427003
# 4 -0.4533753 -0.7472384 -0.6692668 -0.4517765
# 5 -0.2210110 -0.4533753 -0.7472384 -0.6692668

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 9.7.1 Least squares estimation
